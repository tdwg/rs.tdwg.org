# %%
# Script to build JSON-LD pages that provide multilingual labels and definitions controlled vocabularies
# Steve Baskauf 2020 CC0

import re
import requests   # best library to manage HTTP transactions
import csv        # library to read/write/parse CSV files
import json       # library to convert JSON to Python data structures
import pandas as pd

# -----------------
# Configuration section
# -----------------

# Read in mutable configuration variables
with open('config.json', 'rt', encoding='utf-8') as file_object:
    config_text = file_object.read()
config = json.loads(config_text)

# This is the base URL for raw files from the branch of the repo that has been pushed to GitHub. 

github_base_url = 'https://raw.githubusercontent.com/tdwg/rs.tdwg.org/' + config['branch'] + '/'
database_name = config['database_name']

translations_url = github_base_url + database_name + '/' + database_name +'-translations.csv'

has_broader = config['has_broader'] # set to true in configuration file if any terms have skos:broader values
has_exactMatch = config['has_exactMatch'] # set to true of any terms have skos:exactMatch values

label_col_prefix = 'label_'
def_col_prefix = 'definition_'
localname_column_header = 'term_localName'

# ---------------
# Function definitions
# ---------------

# replace URL with link
#
def createLinks(text):
    def repl(match):
        if match.group(1)[-1] == '.':
            return '<a href="' + match.group(1)[:-1] + '">' + match.group(1)[:-1] + '</a>.'
        return '<a href="' + match.group(1) + '">' + match.group(1) + '</a>'

    pattern = '(https?://[^\s,;\)"]*)'
    result = re.sub(pattern, repl, text)
    return result

# %%
frame = pd.read_csv(github_base_url + database_name + '/constants.csv', na_filter=False)
namespace_iri = frame.domainRoot[0]

translations_frame = pd.read_csv(translations_url, na_filter=False)
columns = translations_frame.columns

# Extract the list of languages from the translations spreadsheet column headers
languages = []
for column_header in columns:
    if label_col_prefix in column_header:
        language_code = column_header.split(label_col_prefix)[1]
        if language_code != 'en':
            languages.append(column_header.split(label_col_prefix)[1])
print(languages)
# Out:
# ['es', 'nl']

# %%
# Create a dictionary of language dictionaries for the terms
translations_dictionary = {}
for index,row in translations_frame.iterrows():
    language_dictionary = {}
    for language in languages:
        term_dictionary = {'label': row[label_col_prefix + language], 'definition': row[def_col_prefix + language]}
        language_dictionary[language] = term_dictionary
    translations_dictionary[row[localname_column_header]] = language_dictionary
print(json.dumps(translations_dictionary, indent = 2))
# Out:
# {
#   "e": {
#     "es": {
#       "label": "esquema de conceptos controlado de establishmentMeans",
#       "definition": "Un Esquema de Conceptos de SKOS para ser utilizado como vocabulario controlado para los t\u00e9rminos de Darwin Core dwc:establishmentMeans y dwciri:establishmentMeans"
#     },
#     "nl": {
#       "label": "establishmentMeans gecontroleerd conceptschema",
#       "definition": "Een SKOS Conceptschema te gebruiken als een gecontoleerde woordenschat voor de Darwin Core termen dwc:establishmentMeans en dwciri:establishmentMeans"
#     }
#   },
#   "e001": {
#     "es": {
#       "label": "nativo (aut\u00f3ctono)",
#       "definition": "Un tax\u00f3n que se encuentra dentro de su \u00e1rea de distribuci\u00f3n natural"
#     },
#     "nl": {
#       "label": "inheems",
#       "definition": "Een taxon dat voorkomt binnen zijn natuurlijk verspreidingsgebied"
#     }
#   },
#   "e002": {
#     "es": {
#       "label": "nativo: reintroducido",
#       "definition": "Un tax\u00f3n reestablecido por introducci\u00f3n humana directa en una zona que era parte de su \u00e1rea de distribuci\u00f3n natural, pero en la cual estaba extinguido."
#     },
#     "nl": {
#       "label": "inheems: geherintroduceerd",
#       "definition": "Een taxon dat zich opnieuw vestigde door directe introductie door mensen in een gebied dat oorspronkelijk deel uitmaakte van zijn natuurlijk verspreidingsgebied, maar waar het was uitgestorven."
#     }
#   },
#   "e003": {
#     "es": {
#       "label": "introducido (ex\u00f3tico, no-nativo, no-aut\u00f3ctono)",
#       "definition": "Establecimiento de un tax\u00f3n por acci\u00f3n humana en una zona que no es parte de su \u00e1rea de distribuci\u00f3n natural."
#     },
#     "nl": {
#       "label": "ge\u00efntroduceerd (uitheems, niet-inheems)",
#       "definition": "Vestiging van een taxon door menselijk handelen in een gebied dat geen deel uitmaakt van zijn natuurlijk verspreidingsgebied"
#     }
#   },
#   "e004": {
#     "es": {
#       "label": "introducido: colonizaci\u00f3n asistida",
#       "definition": "Establecimiento de un tax\u00f3n espec\u00edficamente con la intenci\u00f3n de crear una poblaci\u00f3n salvaje autosostenible en una zona que no es parte del \u00e1rea de distribuci\u00f3n natural del tax\u00f3n."
#     },
#     "nl": {
#       "label": "ge\u00efntroduceerd: geassisteerde kolonisatie",
#       "definition": "Vestiging van een taxon specifiek met het doel om een zich zelfonderhoudende wilde populatie te cre\u00ebren in een gebied dat geen deel uitmaakt van het taxon zijn natuurlijk verspreidingsgebied"
#     }
#   },
#   "e005": {
#     "es": {
#       "label": "vagabundo (incidental)",
#       "definition": "La presencia temporaria de un tax\u00f3n muy por afuera de su \u00e1rea de distribuci\u00f3n o de migraci\u00f3n natural."
#     },
#     "nl": {
#       "label": "zwervend (incidenteel)",
#       "definition": "Het tijdelijk voorkomen van een taxon ver buiten zijn natuurlijk verspreidingsgebied of trekgebied."
#     }
#   },
#   "e006": {
#     "es": {
#       "label": "incierto (desconocido, criptog\u00e9nico)",
#       "definition": "El origen de la presencia de un tax\u00f3n en una zona no es bien conocido."
#     },
#     "nl": {
#       "label": "onzeker (onbekend, cryptogeen)",
#       "definition": "De oorsprong van het voorkomen van het taxon in een gebied is onbekend"
#     }
#   }
# }

# %%
term_info = []
frame = pd.read_csv(github_base_url + database_name + '/' + database_name + '.csv', na_filter=False)
for index,row in frame.iterrows():
    term_dict = {}
    term_dict['localname'] = row['term_localName']
    term_dict['iri'] = namespace_iri + row['term_localName']
    term_dict['label'] = []
    term_dict['label'].append({'language': 'en', 'value': row['label']})
    for language in languages:
        term_dict['label'].append({'language': language, 'value': translations_dictionary[row['term_localName']][language]['label']})
    term_dict['definition'] = []
    term_dict['definition'].append({'language': 'en', 'value': row['definition']})
    for language in languages:
        term_dict['definition'].append({'language': language, 'value': translations_dictionary[row['term_localName']][language]['definition']})
    term_dict['cv_string'] = row['controlled_value_string']
    if row['skos_inScheme'] != '':
        term_dict['scheme'] = namespace_iri + row['skos_inScheme']
    else:
        term_dict['scheme'] = ''
    term_dict['type'] = row['type']
    if has_broader:
        if row['skos_broader'] != '':
            term_dict['broader'] = namespace_iri + row['skos_broader']
        else:
            term_dict['broader'] = ''
    if has_exactMatch:
        if row['skos_exactMatch'] != '':
            term_dict['match'] = namespace_iri + row['skos_exactMatch']
        else:
            term_dict['match'] = ''
    term_dict['value'] = row['controlled_value_string']
    term_info.append(term_dict)
print(json.dumps(term_info, indent = 2))
# Out:
# [
#   {
#     "localname": "e",
#     "iri": "http://rs.tdwg.org/dwcem/values/e",
#     "label": [
#       {
#         "language": "en",
#         "value": "establishmentMeans controlled concept scheme"
#       },
#       {
#         "language": "es",
#         "value": "esquema de conceptos controlado de establishmentMeans"
#       },
#       {
#         "language": "nl",
#         "value": "establishmentMeans gecontroleerd conceptschema"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "A SKOS Concept Scheme to be used as a controlled vocabulary for the Darwin Core terms dwc:establishmentMeans and dwciri:establishmentMeans"
#       },
#       {
#         "language": "es",
#         "value": "Un Esquema de Conceptos de SKOS para ser utilizado como vocabulario controlado para los t\u00e9rminos de Darwin Core dwc:establishmentMeans y dwciri:establishmentMeans"
#       },
#       {
#         "language": "nl",
#         "value": "Een SKOS Conceptschema te gebruiken als een gecontoleerde woordenschat voor de Darwin Core termen dwc:establishmentMeans en dwciri:establishmentMeans"
#       }
#     ],
#     "cv_string": "",
#     "scheme": "",
#     "type": "http://www.w3.org/2004/02/skos/core#ConceptScheme",
#     "value": ""
#   },
#   {
#     "localname": "e001",
#     "iri": "http://rs.tdwg.org/dwcem/values/e001",
#     "label": [
#       {
#         "language": "en",
#         "value": "native (indigenous)"
#       },
#       {
#         "language": "es",
#         "value": "nativo (aut\u00f3ctono)"
#       },
#       {
#         "language": "nl",
#         "value": "inheems"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "A taxon occurring within its natural range."
#       },
#       {
#         "language": "es",
#         "value": "Un tax\u00f3n que se encuentra dentro de su \u00e1rea de distribuci\u00f3n natural"
#       },
#       {
#         "language": "nl",
#         "value": "Een taxon dat voorkomt binnen zijn natuurlijk verspreidingsgebied"
#       }
#     ],
#     "cv_string": "native",
#     "scheme": "http://rs.tdwg.org/dwcem/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "value": "native"
#   },
#   {
#     "localname": "e002",
#     "iri": "http://rs.tdwg.org/dwcem/values/e002",
#     "label": [
#       {
#         "language": "en",
#         "value": "native: reintroduced"
#       },
#       {
#         "language": "es",
#         "value": "nativo: reintroducido"
#       },
#       {
#         "language": "nl",
#         "value": "inheems: geherintroduceerd"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "A taxon re-established by direct introduction by humans into an area that was once part of its natural range, but from where it had become extinct."
#       },
#       {
#         "language": "es",
#         "value": "Un tax\u00f3n reestablecido por introducci\u00f3n humana directa en una zona que era parte de su \u00e1rea de distribuci\u00f3n natural, pero en la cual estaba extinguido."
#       },
#       {
#         "language": "nl",
#         "value": "Een taxon dat zich opnieuw vestigde door directe introductie door mensen in een gebied dat oorspronkelijk deel uitmaakte van zijn natuurlijk verspreidingsgebied, maar waar het was uitgestorven."
#       }
#     ],
#     "cv_string": "nativeReintroduced",
#     "scheme": "http://rs.tdwg.org/dwcem/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "value": "nativeReintroduced"
#   },
#   {
#     "localname": "e003",
#     "iri": "http://rs.tdwg.org/dwcem/values/e003",
#     "label": [
#       {
#         "language": "en",
#         "value": "introduced (alien, exotic, non-native, nonindigenous)"
#       },
#       {
#         "language": "es",
#         "value": "introducido (ex\u00f3tico, no-nativo, no-aut\u00f3ctono)"
#       },
#       {
#         "language": "nl",
#         "value": "ge\u00efntroduceerd (uitheems, niet-inheems)"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "Establishment of a taxon by human agency into an area that is not part of its natural range."
#       },
#       {
#         "language": "es",
#         "value": "Establecimiento de un tax\u00f3n por acci\u00f3n humana en una zona que no es parte de su \u00e1rea de distribuci\u00f3n natural."
#       },
#       {
#         "language": "nl",
#         "value": "Vestiging van een taxon door menselijk handelen in een gebied dat geen deel uitmaakt van zijn natuurlijk verspreidingsgebied"
#       }
#     ],
#     "cv_string": "introduced",
#     "scheme": "http://rs.tdwg.org/dwcem/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "value": "introduced"
#   },
#   {
#     "localname": "e004",
#     "iri": "http://rs.tdwg.org/dwcem/values/e004",
#     "label": [
#       {
#         "language": "en",
#         "value": "introduced: assisted colonisation"
#       },
#       {
#         "language": "es",
#         "value": "introducido: colonizaci\u00f3n asistida"
#       },
#       {
#         "language": "nl",
#         "value": "ge\u00efntroduceerd: geassisteerde kolonisatie"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "Establishment of a taxon specifically with the intention of creating a self-sustaining wild population in an area that is not part of the taxon's natural range."
#       },
#       {
#         "language": "es",
#         "value": "Establecimiento de un tax\u00f3n espec\u00edficamente con la intenci\u00f3n de crear una poblaci\u00f3n salvaje autosostenible en una zona que no es parte del \u00e1rea de distribuci\u00f3n natural del tax\u00f3n."
#       },
#       {
#         "language": "nl",
#         "value": "Vestiging van een taxon specifiek met het doel om een zich zelfonderhoudende wilde populatie te cre\u00ebren in een gebied dat geen deel uitmaakt van het taxon zijn natuurlijk verspreidingsgebied"
#       }
#     ],
#     "cv_string": "introducedAssistedColonisation",
#     "scheme": "http://rs.tdwg.org/dwcem/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "value": "introducedAssistedColonisation"
#   },
#   {
#     "localname": "e005",
#     "iri": "http://rs.tdwg.org/dwcem/values/e005",
#     "label": [
#       {
#         "language": "en",
#         "value": "vagrant (casual)"
#       },
#       {
#         "language": "es",
#         "value": "vagabundo (incidental)"
#       },
#       {
#         "language": "nl",
#         "value": "zwervend (incidenteel)"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "The temporary occurrence of a taxon far outside its natural or migratory range."
#       },
#       {
#         "language": "es",
#         "value": "La presencia temporaria de un tax\u00f3n muy por afuera de su \u00e1rea de distribuci\u00f3n o de migraci\u00f3n natural."
#       },
#       {
#         "language": "nl",
#         "value": "Het tijdelijk voorkomen van een taxon ver buiten zijn natuurlijk verspreidingsgebied of trekgebied."
#       }
#     ],
#     "cv_string": "vagrant",
#     "scheme": "http://rs.tdwg.org/dwcem/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "value": "vagrant"
#   },
#   {
#     "localname": "e006",
#     "iri": "http://rs.tdwg.org/dwcem/values/e006",
#     "label": [
#       {
#         "language": "en",
#         "value": "uncertain (unknown, cryptogenic)"
#       },
#       {
#         "language": "es",
#         "value": "incierto (desconocido, criptog\u00e9nico)"
#       },
#       {
#         "language": "nl",
#         "value": "onzeker (onbekend, cryptogeen)"
#       }
#     ],
#     "definition": [
#       {
#         "language": "en",
#         "value": "The origin of the occurrence of the taxon in an area is obscure."
#       },
#       {
#         "language": "es",
#         "value": "El origen de la presencia de un tax\u00f3n en una zona no es bien conocido."
#       },
#       {
#         "language": "nl",
#         "value": "De oorsprong van het voorkomen van het taxon in een gebied is onbekend"
#       }
#     ],
#     "cv_string": "uncertain",
#     "scheme": "http://rs.tdwg.org/dwcem/values/e",
#     "type": "http://www.w3.org/2004/02/skos/core#Concept",
#     "value": "uncertain"
#   }
# ]

# %%
context_dict = {
    "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
    "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
    "skos": "http://www.w3.org/2004/02/skos/core#",
    "xsd": "http://www.w3.org/2001/XMLSchema#",
    "skos:inScheme": {"@type": "@id"}
  }

if has_broader:
    context_dict['skos:broader'] = {"@type": "@id"}

if has_exactMatch:
    context_dict['skos:exactMatch'] = {"@type": "@id"}

graph_list = []
for term in term_info:
    term_dict = {}
    term_dict['@id'] = term['iri']
    term_dict['@type'] = term['type']
    if term['value'] != '':
        term_dict['rdf:value'] = term['value']
    if term['scheme'] != '':
        term_dict['skos:inScheme'] = term['scheme']
    if has_broader:
        if term['broader'] != '':
            term_dict['skos:broader'] = term['broader']
    if has_exactMatch:
        if term['match'] != '':
            term_dict['skos:exactMatch'] = term['match']
    label_list = []
    for lang_label in term['label']:
        label_list.append({'@language': lang_label['language'], '@value': lang_label['value']})
    term_dict['skos:prefLabel'] = label_list
    
    def_list = []
    for lang_label in term['definition']:
        def_list.append({'@language': lang_label['language'], '@value': lang_label['value']})
    term_dict['skos:definition'] = def_list
    
    graph_list.append(term_dict)

output = {"@context": context_dict, "@graph": graph_list}
#jsonld_output = json.dumps(output, indent = 2) # output as escaped characters
jsonld_output = json.dumps(output, indent = 2, ensure_ascii=False) # output at UTF-8 strings
print(jsonld_output)
# Out:
# {
#   "@context": {
#     "rdf": "http://www.w3.org/1999/02/22-rdf-syntax-ns#",
#     "rdfs": "http://www.w3.org/2000/01/rdf-schema#",
#     "skos": "http://www.w3.org/2004/02/skos/core#",
#     "xsd": "http://www.w3.org/2001/XMLSchema#",
#     "skos:inScheme": {
#       "@type": "@id"
#     }
#   },
#   "@graph": [
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e",
#       "@type": "http://www.w3.org/2004/02/skos/core#ConceptScheme",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "establishmentMeans controlled concept scheme"
#         },
#         {
#           "@language": "es",
#           "@value": "esquema de conceptos controlado de establishmentMeans"
#         },
#         {
#           "@language": "nl",
#           "@value": "establishmentMeans gecontroleerd conceptschema"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "A SKOS Concept Scheme to be used as a controlled vocabulary for the Darwin Core terms dwc:establishmentMeans and dwciri:establishmentMeans"
#         },
#         {
#           "@language": "es",
#           "@value": "Un Esquema de Conceptos de SKOS para ser utilizado como vocabulario controlado para los términos de Darwin Core dwc:establishmentMeans y dwciri:establishmentMeans"
#         },
#         {
#           "@language": "nl",
#           "@value": "Een SKOS Conceptschema te gebruiken als een gecontoleerde woordenschat voor de Darwin Core termen dwc:establishmentMeans en dwciri:establishmentMeans"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e001",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "native",
#       "skos:inScheme": "http://rs.tdwg.org/dwcem/values/e",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "native (indigenous)"
#         },
#         {
#           "@language": "es",
#           "@value": "nativo (autóctono)"
#         },
#         {
#           "@language": "nl",
#           "@value": "inheems"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "A taxon occurring within its natural range."
#         },
#         {
#           "@language": "es",
#           "@value": "Un taxón que se encuentra dentro de su área de distribución natural"
#         },
#         {
#           "@language": "nl",
#           "@value": "Een taxon dat voorkomt binnen zijn natuurlijk verspreidingsgebied"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e002",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "nativeReintroduced",
#       "skos:inScheme": "http://rs.tdwg.org/dwcem/values/e",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "native: reintroduced"
#         },
#         {
#           "@language": "es",
#           "@value": "nativo: reintroducido"
#         },
#         {
#           "@language": "nl",
#           "@value": "inheems: geherintroduceerd"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "A taxon re-established by direct introduction by humans into an area that was once part of its natural range, but from where it had become extinct."
#         },
#         {
#           "@language": "es",
#           "@value": "Un taxón reestablecido por introducción humana directa en una zona que era parte de su área de distribución natural, pero en la cual estaba extinguido."
#         },
#         {
#           "@language": "nl",
#           "@value": "Een taxon dat zich opnieuw vestigde door directe introductie door mensen in een gebied dat oorspronkelijk deel uitmaakte van zijn natuurlijk verspreidingsgebied, maar waar het was uitgestorven."
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e003",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "introduced",
#       "skos:inScheme": "http://rs.tdwg.org/dwcem/values/e",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "introduced (alien, exotic, non-native, nonindigenous)"
#         },
#         {
#           "@language": "es",
#           "@value": "introducido (exótico, no-nativo, no-autóctono)"
#         },
#         {
#           "@language": "nl",
#           "@value": "geïntroduceerd (uitheems, niet-inheems)"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "Establishment of a taxon by human agency into an area that is not part of its natural range."
#         },
#         {
#           "@language": "es",
#           "@value": "Establecimiento de un taxón por acción humana en una zona que no es parte de su área de distribución natural."
#         },
#         {
#           "@language": "nl",
#           "@value": "Vestiging van een taxon door menselijk handelen in een gebied dat geen deel uitmaakt van zijn natuurlijk verspreidingsgebied"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e004",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "introducedAssistedColonisation",
#       "skos:inScheme": "http://rs.tdwg.org/dwcem/values/e",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "introduced: assisted colonisation"
#         },
#         {
#           "@language": "es",
#           "@value": "introducido: colonización asistida"
#         },
#         {
#           "@language": "nl",
#           "@value": "geïntroduceerd: geassisteerde kolonisatie"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "Establishment of a taxon specifically with the intention of creating a self-sustaining wild population in an area that is not part of the taxon's natural range."
#         },
#         {
#           "@language": "es",
#           "@value": "Establecimiento de un taxón específicamente con la intención de crear una población salvaje autosostenible en una zona que no es parte del área de distribución natural del taxón."
#         },
#         {
#           "@language": "nl",
#           "@value": "Vestiging van een taxon specifiek met het doel om een zich zelfonderhoudende wilde populatie te creëren in een gebied dat geen deel uitmaakt van het taxon zijn natuurlijk verspreidingsgebied"
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e005",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "vagrant",
#       "skos:inScheme": "http://rs.tdwg.org/dwcem/values/e",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "vagrant (casual)"
#         },
#         {
#           "@language": "es",
#           "@value": "vagabundo (incidental)"
#         },
#         {
#           "@language": "nl",
#           "@value": "zwervend (incidenteel)"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "The temporary occurrence of a taxon far outside its natural or migratory range."
#         },
#         {
#           "@language": "es",
#           "@value": "La presencia temporaria de un taxón muy por afuera de su área de distribución o de migración natural."
#         },
#         {
#           "@language": "nl",
#           "@value": "Het tijdelijk voorkomen van een taxon ver buiten zijn natuurlijk verspreidingsgebied of trekgebied."
#         }
#       ]
#     },
#     {
#       "@id": "http://rs.tdwg.org/dwcem/values/e006",
#       "@type": "http://www.w3.org/2004/02/skos/core#Concept",
#       "rdf:value": "uncertain",
#       "skos:inScheme": "http://rs.tdwg.org/dwcem/values/e",
#       "skos:prefLabel": [
#         {
#           "@language": "en",
#           "@value": "uncertain (unknown, cryptogenic)"
#         },
#         {
#           "@language": "es",
#           "@value": "incierto (desconocido, criptogénico)"
#         },
#         {
#           "@language": "nl",
#           "@value": "onzeker (onbekend, cryptogeen)"
#         }
#       ],
#       "skos:definition": [
#         {
#           "@language": "en",
#           "@value": "The origin of the occurrence of the taxon in an area is obscure."
#         },
#         {
#           "@language": "es",
#           "@value": "El origen de la presencia de un taxón en una zona no es bien conocido."
#         },
#         {
#           "@language": "nl",
#           "@value": "De oorsprong van het voorkomen van het taxon in een gebied is onbekend"
#         }
#       ]
#     }
#   ]
# }

# %%
# outputObject = open(out_filename, 'wt', encoding='utf-8') # use with escaped characters
for out_filename in [database_name + '.json', database_name + '.jsonld']:
    outputObject = open(out_filename, 'w', encoding='utf-8') # use with UTF-8 strings
    outputObject.write(jsonld_output)
    outputObject.close()
    
print('done')
# Out:
# done
